# %% [markdown]
# ### preliminaries

# %%
pwd
# Out:
# '/root/src/github.com/j-faria/kima-them-all/runs/14Her'

# %%
ls
# Out:
# 14her.rv              kima_setup.cpp  Makefile     report.ipynb
# kima*                 kima_setup.o    OPTIONS      sample_info.txt
# kima_model_setup.txt  levels.txt      report.html  sample.txt

# %% [markdown]
# ### make some plots!

# %%
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = [8, 6]
matplotlib.rcParams['font.size'] = 16

# %%
import pykima

# %% [markdown]
# #### diagnostic

# %%
res = pykima.showresults('diagnostic')
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# log(Z) = -512.8077695410706
# Information = 26.21373367997421 nats.
# Effective sample size = 166.46808358200596
# Loading data file 14her.rv

# %% [markdown]
# #### analysis

# %%
res.make_plot1()
# Out:
# Np probability ratios:  []

# %%
res.make_plot2()

# %%
res.make_plot3()

# %%
res.make_plot4()
# Out:
# Model does not have GP! make_plot4() doing nothing...

# %%
res.make_plot5()
# Out:
# Model does not have GP! make_plot5() doing nothing...

# %%
res.plot_random_planets()

# %%
res.hist_offset()
res.hist_vsys()
res.hist_extra_sigma()
res.hist_trend()
# Out:
# Model has no fiber offset! hist_offset() doing nothing...
# Model has no trend! hist_trend() doing nothing...
